# %% [markdown]
# # Example usage
#
# To use `tidypandas` in a project:

# %%
import tidypandas
import numpy as np

print(tidypandas.__version__)
# Out:
# 0.0.1

# %%
from tidypandas import tidyframe
from tidypandas.tidy_utils import simplify
from palmerpenguins import load_penguins
import pandas.api.types as dtypes
penguins_tidy = tidyframe(load_penguins())
penguins_tidy
# Out:
# /media/dattachidambara/New Volume/code/tidypandas/src/tidypandas/tidy_utils.py:225: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   if isinstance(pdf.index, (pd.RangeIndex, pd.Int64Index)):
# # A tidy dataframe: 344 X 8
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
#       <string>   <string>       <Float64>      <Float64>            <Int64>
# 0       Adelie  Torgersen            39.1           18.7                181
# 1       Adelie  Torgersen            39.5           17.4                186
# 2       Adelie  Torgersen            40.3           18.0                195
# 3       Adelie  Torgersen            <NA>           <NA>               <NA>
# ..         ...        ...             ...            ...                ...
# 4       Adelie  Torgersen            36.7           19.3                193
# ...

# %%
# penguins_tidy.mutate({'blmm': lambda x: x['bill_length_mm'] + 1}, by = 'species')

# penguins_tidy.group_modify(lambda x: x.assign(blmm = lambda x: x['bill_length_mm'] + 1)
#                            , by = 'species'
#                            , is_pandas_udf = True
#                           )

(penguins_tidy.to_pandas()
              .assign(__rn = lambda x: np.arange(x.shape[0]))
              .groupby('sex', dropna = False)
              .apply(lambda x: x.assign(blmm = lambda x: x['bill_length_mm'] + 1))
              .drop(columns = "__rn")
              .pipe(simplify)
#               .reset_index(drop = True)
#               .sort_values(by = "__rn")
#               .drop(columns = "__rn")
              )
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0       Adelie  Torgersen            39.1           18.7                181
# 1       Adelie  Torgersen            39.5           17.4                186
# 2       Adelie  Torgersen            40.3           18.0                195
# 3       Adelie  Torgersen            <NA>           <NA>               <NA>
# 4       Adelie  Torgersen            36.7           19.3                193
# ..         ...        ...             ...            ...                ...
# 339  Chinstrap      Dream            55.8           19.8                207
# 340  Chinstrap      Dream            43.5           18.1                202
# 341  Chinstrap      Dream            49.6           18.2                193
# 342  Chinstrap      Dream            50.8           19.0                210
# 343  Chinstrap      Dream            50.2           18.7                198
#
#      body_mass_g     sex  year  blmm
# ...

# %%
dir()
# Out:
# ['In',
#  'Out',
#  '_',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_dh',
#  '_exit_code',
#  '_i',
#  '_i1',
#  '_i2',
#  '_i3',
#  '_i4',
#  '_i5',
#  '_ih',
#  '_ii',
#  '_iii',
#  '_oh',
#  'exit',
#  'format',
#  'get_ipython',
#  'quit',
#  'tidy_utils',
#  'tidyframe',
#  'tidypandas']

# %%
# hello world
